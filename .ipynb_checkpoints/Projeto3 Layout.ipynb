# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 3 - INSPER

# %% [markdown]
# ___
# ## Alexandre Edington
#
# ## Bruno Cury
#
# ## Matheus Soares
#
# ___

# %% [markdown]
# ___
#
# ## INTRODUÇÃO

# %% [markdown]
# Não vem de hoje o grande interesse da sociedade em vídeo games, porém, há aproximadamente dez anos atrás, a visão que tínhamos sobre o ato de jogar vídeo game e sua indústria era completamente diferente.
# Em 2007 os jogos com maiores ambições comerciais projetavam um lucro multimilionário e a venda dos mesmos era feita através de discos que seriam rodados em seu console de preferência.
# Hoje em dia os consoles são apenas uma parcela do vasto universo de aparelhos que rodam vídeo games, e a venda destes jogos já não se da mais por discos, sua grande maioria vem de downloads e seus lucros são projetados na faixa dos biliões de dólares. Os videogames são agora, onipresentes em nossas vidas, qualquer um com um smartphone tem acesso a uma variedade de jogos, disponíveis na plataforma de download do seu sistema operacional (iOS, Android, google play), ou até nas redes sociais como Facebook, que se tornou uma grande plataforma de jogos online.
# Com isso em mente, resolvemos analisar os dados da maior plataforma de download de vídeo games da internet, afim de quantificar o impacto dos jogos no mundo por meio da análise de suas características mais importantes. E então, a partir desta análise, predizer o sucesso (ou falta dele) na arrecadação mundial de algum jogo, através do input de algumas de suas características.

# %% [markdown]
# ___
# ## MINERANDO DADOS e CARACTERÍSTICAS DO DATASET

# %% [markdown]
# Os dados utilizados neste experimento foram retirados na integra do site data.world, onde são disponibilizados diversos bancos de dados; o Dataset escolhido é inteiramente referente às características dos jogos disponíveis na plataforma Steam. Inicialmente, o banco de dados em questão contava com mais de 70 variáveis e uma ampla quantidade de dados, porém o mesmo precisou ser filtrado, em prol da eficiência e organização foi feita a retirada de variáveis indesejadas e a retirada de dados nulos. Escolhemos também agrupar algumas variáveis, como as entradas de gênero (Indie, Action, Adventure, Casual, Strategy, RPG, Simulation, Sports, Racing), que se tornaram uma só variável, assim como a compatibilidade com Mac, Linux e Windows se tornaram uma só entrada.

# %%
import pandas as pd
import os

# %%
df = pd.read_csv("games-features.csv",error_bad_lines=False,sep=";")

# %% [markdown]
# ### BASE DE DADOS

# %%
dados = pd.DataFrame()
dados["NOME"] = df["ResponseName"]
dados["LANCAMENTO"] = df["ReleaseDate"]
dados["IDADE_MINIMA"] = df["RequiredAge"]
dados["LINGUAS"] = df["SupportedLanguages"]
#dados["PLATAFORMA_WINDOWS"] = df["PlatformWindows"]
#dados["PLATAFORMA_MAC"] = df["PlatformMac"]
#dados["PLATAFORMA_LINUX"] = df["PlatformLinux"]
#dados["MULTIPLAYER"] = df["CategoryMultiplayer"]
#dados["SINGLE_PLAYER"] = df["CategorySinglePlayer"]
#dados["COOP"] = df["CategoryCoop"]
dados["INDIE"] = df["GenreIsIndie"]
dados["ACTION"] = df["GenreIsAction"]
dados["ADVENTURE"] = df["GenreIsAdventure"]
dados["CASUAL"] = df["GenreIsCasual"]
dados["STRATEGY"] = df["GenreIsStrategy"]
dados["RPG"] = df["GenreIsRPG"]
dados["SIMULATION"] = df["GenreIsSimulation"]
dados["SPORTS"] = df["GenreIsSports"]
dados["RACING"] = df["GenreIsRacing"]
dados["NUM_PROPRIETARIOS"] = df["SteamSpyOwners"]
dados["PRECO_INICIAL"] = df["PriceInitial"]
dados["PRECO_FINAL"] = df["PriceFinal"]

# %%
def Plataforma(df):
    a = df.PlatformWindows
    b = df.PlatformMac
    c = df.PlatformLinux
    
    if (a == "VERDADEIRO" and b == "VERDADEIRO" and c == "VERDADEIRO"): return "Windows, Linux e Mac"
    elif (a == "VERDADEIRO" and b == "VERDADEIRO" and c == "FALSO"): return "Windows e Mac"
    elif (a == "VERDADEIRO" and b == "FALSO" and c == "FALSO"): return "Windows"
    elif (a == "FALSO" and b == "VERDADEIRO" and c == "VERDADEIRO"): return "Mac e Linux"
    elif (a == "FALSO" and b == "VERDADEIRO" and c == "FALSO"): return "Mac"
    elif (a == "VERDADEIRO" and b == "FALSO" and c == "VERDADEIRO"): return "Windows e Linux"
    elif (a == "FALSO" and b == "FALSO" and c == "VERDADEIRO"): return "Linux"
    else: return "Nenhuma Plataforma"

Input = df.apply(Plataforma,axis=1)
dados["PLATAFORMAS"] = Input


def Jogabilidade(df):
    a = df.CategoryMultiplayer
    b = df.CategorySinglePlayer
    c = df.CategoryCoop
    
    if (a == "VERDADEIRO" and b == "VERDADEIRO" and c == "VERDADEIRO"): return "MultiPlayer, SinglePlayer e Coop"
    elif (a == "VERDADEIRO" and b == "VERDADEIRO" and c == "FALSO"): return "MultiPlayer e SinglePlayer"
    elif (a == "VERDADEIRO" and b == "FALSO" and c == "FALSO"): return "MultiPlyer"
    elif (a == "FALSO" and b == "VERDADEIRO" and c == "VERDADEIRO"): return "SinglePlayer e Coop"
    elif (a == "FALSO" and b == "VERDADEIRO" and c == "FALSO"): return "SinglePlayer"
    elif (a == "VERDADEIRO" and b == "FALSO" and c == "VERDADEIRO"): return "MultiPlayer e Coop"
    elif (a == "FALSO" and b == "FALSO" and c == "VERDADEIRO"): return "Coop"
    else: return "N/"
    
Input2 = df.apply(Jogabilidade,axis=1)
dados["JOGABILIDADE"] = Input2

# %%
dados
# Out:
#                                                     NOME  LANCAMENTO  \
# 0                                         Counter-Strike  01/11/2000
# 1                                  Team Fortress Classic  01/04/1999
# 2                                          Day of Defeat  01/05/2003
# 3                                     Deathmatch Classic  01/06/2001
# 4                              Half-Life: Opposing Force  01/11/1999
# 5                                               Ricochet  01/11/2000
# 6                                              Half-Life  08/11/1998
# 7                         Counter-Strike: Condition Zero  01/03/2004
# 8                         Counter-Strike: Condition Zero  01/03/2004
# 9                                  Half-Life: Blue Shift  01/06/2001
# 10                                           Half-Life 2  16/11/2004
# 11                                Counter-Strike: Source  01/11/2004
# 12                                     Half-Life: Source  01/06/2004
# 13                                 Day of Defeat: Source  12/07/2010
# 14                               Half-Life 2: Deathmatch  01/11/2004
  VERDADEIRO       FALSO       FALSO       FALSO       FALSO
# 13333       FALSO  VERDADEIRO  VERDADEIRO       FALSO       FALSO       FALSO
# 13334       FALSO       FALSO  VERDADEIRO  VERDADEIRO       FALSO       FALSO
# 13335       FALSO       FALSO  VERDADEIRO  VERDADEIRO       FALSO       FALSO
# 13336  VERDADEIRO  VERDADEIRO  VERDADEIRO  VERDADEIRO       FALSO       FALSO
# 13337  VERDADEIRO  VERDADEIRO  VERDADEIRO       FALSO       FALSO       FALSO
# 13338  VERDADEIRO  VERDADEIRO  VERDADEIRO  VERDADEIRO       FALSO  VERDADEIRO
# 13339  VERDADEIRO       FALSO       FALSO  VERDADEIRO       FALSO       FALSO
# 13340  VERDADEIRO       FALSO  VERDADEIRO       FALSO  VERDADEIRO  VERDADEIRO
# 13341  VERDADEIRO  VERDADEIRO       FALSO  VERDADEIRO       FALSO       FALSO
# 13342       FALSO       FALSO       FALSO       FALSO       FALSO       FALSO
# 13343       FALSO       FALSO       FALSO  VERDADEIRO       FALSO       FALSO
# 13344  VERDADEIRO  VERDADEIRO       FALSO       FALSO       FALSO       FALSO
# 13345  VERDADEIRO       FALSO       FALSO  VERDADEIRO       FALSO       FALSO
# 13346  VERDADEIRO       FALSO       FALSO  VERDADEIRO       FALSO       FALSO
# 13347  VERDADEIRO       FALSO       FALSO  VERDADEIRO       FALSO       FALSO
# 13348  VERDADEIRO  VERDADEIRO  VERDADEIRO  VERDADEIRO       FALSO       FALSO
# 13349  VERDADEIRO  VERDADEIRO       FALSO  VERDADEIRO       FALSO       FALSO
# 13350  VERDADEIRO       FALSO  VERDADEIRO  VERDADEIRO  VERDADEIRO       FALSO
#
#        SIMULATION      SPORTS      RACING  NUM_PROPRIETARIOS  PRECO_INICIAL  \
# 0           FALSO       FALSO       FALSO           13033334            999
# 1           FALSO       FALSO       FALSO            5399140            499
# 2           FALSO       FALSO       FALSO            7621102            499
# 3           FALSO       FALSO       FALSO            7498965            499
# 4           FALSO       FALSO       FALSO            5399499            499
# 5           FALSO       FALSO       FALSO            7488563            499
# 6           FALSO       FALSO       FALSO            5927504            999
# 7           FALSO       FALSO       FALSO           10489261            999
# 8           FALSO       FALSO       FALSO           10489261            999
# 9           FALSO       FALSO       FALSO            5368650            499
# 10          FALSO       FALSO       FALSO            9901173            999
# 11          FALSO       FALSO       FALSO           15433570           1999
# 12          FALSO       FALSO       FALSO            2983660            999
# 13          FALSO       FALSO       FALSO            6400269            999
# 14          FALSO       FALSO       FALSO           14001822            499
# 15          FALSO       FALSO       FALSO           14844765              0
# 16          FALSO       FALSO       FALSO            6796273            999
# 17          FALSO       FALSO       FALSO            6298399            799
# 18          FALSO       FALSO       FALSO            9795716            999
# 19          FALSO       FALSO       FALSO            5735062            799
# 20          FALSO       FALSO       FALSO           37878812              0
# 21          FALSO       FALSO       FALSO            4473517           1999
# 22          FALSO       FALSO       FALSO           15574539           1999
# 23          FALSO       FALSO       FALSO           90687580              0
# 24          FALSO       FALSO       FALSO            8741499           1999
# 25          FALSO       FALSO       FALSO            4819841              0
# 26          FALSO       FALSO       FALSO            8741499           1999
# 27          FALSO       FALSO       FALSO           25833156           1499
# 28          FALSO       FALSO       FALSO              35332            999
# 29          FALSO       FALSO       FALSO             940689            999
# ...           ...         ...         ...                ...            ...
# 13321       FALSO       FALSO       FALSO                  0           1499
# 13322       FALSO       FALSO       FALSO                  0           1299
# 13323       FALSO       FALSO       FALSO                  0              0
# 13324       FALSO       FALSO       FALSO                  0           1299
# 13325       FALSO       FALSO       FALSO                  0            599
# 13326       FALSO       FALSO       FALSO                  0              0
# 13327       FALSO       FALSO       FALSO                  0              0
# 13328  VERDADEIRO       FALSO       FALSO                  0            199
# 13329       FALSO       FALSO       FALSO                  0              0
# 13330       FALSO       FALSO       FALSO                  0              0
# 13331       FALSO       FALSO       FALSO                  0              0
# 13332       FALSO       FALSO  VERDADEIRO                808             99
# 13333       FALSO       FALSO       FALSO                  0           1499
# 13334       FALSO       FALSO       FALSO                  0              0
# 13335       FALSO       FALSO       FALSO                  0              0
# 13336       FALSO       FALSO       FALSO                  0              0
# 13337       FALSO       FALSO  VERDADEIRO                  0            599
# 13338       FALSO       FALSO       FALSO                  0              0
# 13339       FALSO  VERDADEIRO       FALSO                  0              0
# 13340       FALSO       FALSO       FALSO                  0              0
# 13341       FALSO       FALSO       FALSO                  0              0
# 13342       FALSO  VERDADEIRO       FALSO                  0              0
# 13343       FALSO       FALSO       FALSO                  0            399
# 13344       FALSO       FALSO       FALSO                  0              0
# 13345       FALSO       FALSO       FALSO                  0            199
# 13346       FALSO  VERDADEIRO       FALSO                  0              0
# 13347       FALSO       FALSO       FALSO                  0              0
# 13348       FALSO       FALSO       FALSO                  0              0
# 13349       FALSO  VERDADEIRO       FALSO                  0              0
# 13350       FALSO       FALSO       FALSO                  0              0
#
#        PRECO_FINAL           PLATAFORMAS                      JOGABILIDADE
# 0              999  Windows, Linux e Mac                        MultiPlyer
# 1              499  Windows, Linux e Mac                        MultiPlyer
# 2              499  Windows, Linux e Mac                        MultiPlyer
# 3              499  Windows, Linux e Mac                        MultiPlyer
# 4              499  Windows, Linux e Mac        MultiPlayer e SinglePlayer
# 5              499  Windows, Linux e Mac                        MultiPlyer
# 6              999  Windows, Linux e Mac        MultiPlayer e SinglePlayer
# 7              999  Windows, Linux e Mac        MultiPlayer e SinglePlayer
# 8              999  Windows, Linux e Mac        MultiPlayer e SinglePlayer
# 9              499  Windows, Linux e Mac                      SinglePlayer
# 10             999  Windows, Linux e Mac                      SinglePlayer
# 11            1999  Windows, Linux e Mac                        MultiPlyer
# 12             999  Windows, Linux e Mac                      SinglePlayer
# 13             999  Windows, Linux e Mac                        MultiPlyer
# 14             499  Windows, Linux e Mac                        MultiPlyer
# 15               0  Windows, Linux e Mac                      SinglePlayer
# 16             999  Windows, Linux e Mac                        MultiPlyer
# 17             799  Windows, Linux e Mac                      SinglePlayer
# 18             999  Windows, Linux e Mac                      SinglePlayer
# 19             799  Windows, Linux e Mac                      SinglePlayer
# 20               0  Windows, Linux e Mac                        MultiPlyer
# 21            1999         Windows e Mac  MultiPlayer, SinglePlayer e Coop
# 22            1999  Windows, Linux e Mac  MultiPlayer, SinglePlayer e Coop
# 23               0  Windows, Linux e Mac                MultiPlayer e Coop
# 24            1999  Windows, Linux e Mac               SinglePlayer e Coop
# 25               0               Windows  MultiPlayer, SinglePlayer e Coop
# 26            1999  Windows, Linux e Mac               SinglePlayer e Coop
# 27            1499  Windows, Linux e Mac                        MultiPlyer
# 28             999               Windows        MultiPlayer e SinglePlayer
# 29             999  Windows, Linux e Mac                        MultiPlyer
# ...            ...                   ...                               ...
# 13321         1499               Windows                      SinglePlayer
# 13322         1299               Windows                      SinglePlayer
# 13323            0  Windows, Linux e Mac                      SinglePlayer
# 13324         1299               Windows                      SinglePlayer
# 13325          599               Windows                      SinglePlayer
# 13326            0               Windows        MultiPlayer e SinglePlayer
# 13327            0               Windows                      SinglePlayer
# 13328          199               Windows                      SinglePlayer
# 13329            0               Windows                      SinglePlayer
# 13330            0               Windows                      SinglePlayer
# 13331            0               Windows                      SinglePlayer
# 13332           59               Windows                      SinglePlayer
# 13333         1049               Windows                      SinglePlayer
# 13334            0               Windows                      SinglePlayer
# 13335            0               Windows                      SinglePlayer
# 13336            0               Windows                      SinglePlayer
# 13337          509               Windows                      SinglePlayer
# 13338            0               Windows                      SinglePlayer
# 13339            0               Windows                      SinglePlayer
# 13340            0         Windows e Mac                      SinglePlayer
# 13341            0               Windows                      SinglePlayer
# 13342            0               Windows                      SinglePlayer
# 13343          399               Windows                      SinglePlayer
# 13344            0               Windows                      SinglePlayer
# 13345          159               Windows                      SinglePlayer
# 13346            0               Windows                      SinglePlayer
# 13347            0               Windows                      SinglePlayer
# 13348            0               Windows                      SinglePlayer
# 13349            0               Windows  MultiPlayer, SinglePlayer e Coop
# 13350            0         Windows e Mac                      SinglePlayer
#
# [13351 rows x 18 columns]

# %% [markdown]
# ### ANÁLISE DESCRITIVA

# %% [markdown]
# ___
# ## MODELOS DE PREDIÇÃO

# %% [markdown]
# [O tópico C.PROCESSO E ESTATÍSTICAS DE VALIDAÇÃO estará dentro deste tópico. Organize-o aqui de forma clara!]
#
# [ORGANIZE AQUI TODOS OS MODELOS DE PREDIÇÃO NECESSÁRIOS NESTE PROJETO!]

# %% [markdown]
# o MODELO DE PREDIÇÃO PELA MÉDIA
#
# o MODELO DOS K VIZINHOS MAIS PRÓXIMOS (K-Nearest Neighbors Regression)
#
# o MODELO DE REGRESSÃO LINEAR (Multiple Linear Regression)
#
# o MODELO DE ÁRVORES DE REGRESSÃO (Decision Tree Regression)

# %% [markdown]
# ___
# ## CONCLUSÃO

# %% [markdown]
# ___
# ## REFERÊNCIAS BIBLIOGRÁFICAS
